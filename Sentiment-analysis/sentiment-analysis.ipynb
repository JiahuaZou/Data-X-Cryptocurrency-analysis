# %% [markdown]
# # Data-X Project

# %%
import csv
import re
import numpy as np
import pandas as pd 
import seaborn as sns
import gensim
import spacy
import nltk
nltk.download('wordnet')
lemmatizer = nltk.stem.WordNetLemmatizer()
ps = nltk.PorterStemmer()
import matplotlib.pyplot as plt
from matplotlib import pyplot
from nltk.corpus import stopwords
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package wordnet to /srv/app/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## Sentiment Analysis for Cryptocurrency Hashtag on Twitter

# %% [markdown]
# We will use the VADER (Valence Aware Dictionary and sEntiment Reasoner) lexicon to analyze the sentiment of Cryptocurrency-related tweets.
#
# VADER is a lexicon and rule-based sentiment analysis tool that is specifically attuned to sentiments expressed in social media which is great for our usage.
#
# You can find more about this at https://github.com/cjhutto/vaderSentiment

# %% [markdown]
# ### 1.Read the files into pandas dataframe

# %%
### Tweets 1 consists of all the cryptocurrency related tweets from Oct 20 to Oct 27, 2018. 
### Tweets 2 consists of all the cryptocurrency related tweets from Nov 1 to Nov 9, 2018

# %%
tweets1 = pd.read_csv("bitcoin.csv")[['Author', 'Text', 'Retweet_Count', 'Timestamp']]
tweets1.head()
# Out:
#             Author                                               Text  \
# 0     ewin74698177  RT @SolarisCoin: Take a peek @ https://t.co/W8...
# 1      thegustians  RT @SolarisCoin: Take a peek @ https://t.co/W8...
# 2            frg_x  RT @SolarisCoin: Take a peek @ https://t.co/W8...
# 3    TechniCraftCZ  RT @CryptoPepes: CryptoPepes just soft launche...
# 4  victordorofeev1  RT @SolarisCoin: Take a peek @ https://t.co/W8...
#
#    Retweet_Count            Timestamp
# 0             49  2018-10-27 23:25:41
# 1             49  2018-10-27 23:10:20
# 2             49  2018-10-27 23:07:04
# 3             93  2018-10-27 23:02:48
# 4             49  2018-10-27 23:01:47

# %%
tweets2 = pd.read_csv('bitcointweets.csv')[['Author', 'Text', 'Retweet_Count', 'Timestamp']]
tweets2.head()
# Out:
#             Author                                               Text  \
# 0  Sharp_or_Parish  Booooommmmmmm!\r\n\r\n4th POD HAMMER BOMB to t...
# 1   T45Investments  5.00 GMT Update!\r\n#trading #futures #commodi...
# 2       ArbingTool  #DASH\r\nBuy at #Koinim and sell at #YoBit. Ra...
# 3       ArbingTool  #ETH\r\nBuy at #Bitstamp and sell at #Bittrex....
# 4       ArbingTool  #XRP\r\nBuy at #Bitstamp and sell at #Bitfinex...
#
#    Retweet_Count            Timestamp
# 0              0  2018-11-09 06:13:30
# 1              0  2018-11-09 06:03:09
# 2              0  2018-11-09 06:01:30
# 3              0  2018-11-09 06:01:21
# 4              0  2018-11-09 06:01:12

# %% [markdown]
# ### 2. Data cleaning function:
# Remove urls, mentions, punctuations and stopwords

# %%
class CleanText():
    
    def __init__(self, input_text):
        self.input_text = input_text
    
    def remove(self):
        remove_mention = re.sub(r'@\w+', '', self.input_text)
        remove_url = re.sub(r'http.?://[^\s]+[\s]?', '', remove_mention)
        # By compressing the underscore, the emoji is kept as one word
        remove_emoji = remove_url.replace('_','')
        remove_punctuation = re.sub('[^A-Za-z0-9_\s]', '', remove_emoji)
        lowercase = remove_punctuation.lower()
        remove_n = re.sub('[\n\r]', '', lowercase)
        remove_num = re.sub('[[:digit:]]', '', remove_n)
        
        return remove_num.replace('rt', '')

# %%
clean_tweet1 = []
for tweet in tweets1['Text']:
    clean_tweet1.append(CleanText(tweet).remove())
    
clean_tweets1 = tweets1.drop(['Text'], axis = 1)
clean_tweets1['Clean_Text'] = clean_tweet1
clean_tweets1.head()

clean_tweet2 = []
for tweet in tweets2['Text']:
    clean_tweet2.append(CleanText(tweet).remove())
    
clean_tweets2 = tweets2.drop(['Text'], axis = 1)
clean_tweets2['Clean_Text'] = clean_tweet2
clean_tweets2.head()
# Out:
#             Author  Retweet_Count            Timestamp  \
# 0  Sharp_or_Parish              0  2018-11-09 06:13:30
# 1   T45Investments              0  2018-11-09 06:03:09
# 2       ArbingTool              0  2018-11-09 06:01:30
# 3       ArbingTool              0  2018-11-09 06:01:21
# 4       ArbingTool              0  2018-11-09 06:01:12
#
#                                           Clean_Text
# 0  booooommmmmmm4th pod hammer bomb to the window...
# 1  500 gmt updatetrading futures commodities euru...
# 2  dashbuy at koinim and sell at yobit ratio 116b...
# 3  ethbuy at bitstamp and sell at bittrex ratio 0...
# 4  xrpbuy at bitstamp and sell at bitfinex ratio ...

# %%
def tokenize(text):
    tokens = re.split('\W+', text)
    return tokens

clean_tweets1['tokenized_clean_text'] = clean_tweets1['Clean_Text'].apply(lambda x: tokenize(x.lower()))
clean_tweets1.head()
# Out:
#             Author  Retweet_Count            Timestamp  \
# 0     ewin74698177             49  2018-10-27 23:25:41
# 1      thegustians             49  2018-10-27 23:10:20
# 2            frg_x             49  2018-10-27 23:07:04
# 3    TechniCraftCZ             93  2018-10-27 23:02:48
# 4  victordorofeev1             49  2018-10-27 23:01:47
#
#                                           Clean_Text  \
# 0    take a peek  would you like to test it soon ...
# 1    take a peek  would you like to test it soon ...
# 2    take a peek  would you like to test it soon ...
# 3    cryptopepes just soft launched on ethereum m...
# 4    take a peek  would you like to test it soon ...
#
#                                 tokenized_clean_text  compound
# 0  [, take, a, peek, would, you, like, to, test, ...    0.8316
# 1  [, take, a, peek, would, you, like, to, test, ...    0.8316
# 2  [, take, a, peek, would, you, like, to, test, ...    0.8316
# 3  [, cryptopepes, just, soft, launched, on, ethe...    0.1280
# 4  [, take, a, peek, would, you, like, to, test, ...    0.8316

# %% [markdown]
# ### 3. Sentiment analysis
#
# We will look at the compound score for each sentence.

# %%
analyzer = SentimentIntensityAnalyzer()

score1 = []
for sentence in clean_tweets1['Clean_Text']:
    score1.append(analyzer.polarity_scores(sentence))

sentiment1 = []
for each in score1:
    sentiment1.append(each['compound'])
clean_tweets1['compound'] = sentiment1

score2 = []
for sentence in clean_tweets2['Clean_Text']:
    score2.append(analyzer.polarity_scores(sentence))

sentiment2 = []
for each in score2:
    sentiment2.append(each['compound'])
clean_tweets2['compound'] = sentiment2

# %% [markdown]
# The threshold for positive comment is >= 0.05, for neutral comment is > - 0.05 and for negative comment is <= -0.05.
#
# We will classify the tweets using this threshold.

# %%
comment_class = []
for score in clean_tweets1['compound']:
    if score <= -0.05:
        comment_class.append('Negative')
    elif score >= 0.05:
        comment_class.append('Positive')
    else:
        comment_class.append('Neutral')
clean_tweets1['type'] = comment_class

comment_class = []
for score in clean_tweets2['compound']:
    if score <= -0.05:
        comment_class.append('Negative')
    elif score >= 0.05:
        comment_class.append('Positive')
    else:
        comment_class.append('Neutral')
clean_tweets2['type'] = comment_class

# %% [markdown]
# ### 4. Compute length of each tweets and write both of them to csv file

# %%
clean_tweets1['text_len'] = [len(text) for text in clean_tweets1['Clean_Text']]
x1 = clean_tweets1[['compound', 'text_len']]
x1.to_csv('x1.csv')

# %%
clean_tweets2['text_len'] = [len(text) for text in clean_tweets2['Clean_Text']]
x2 = clean_tweets2[['compound', 'text_len']]
x2.to_csv('x2.csv')

# %%
x1
# Out:
#       compound  text_len
# 0       0.8316        92
# 1       0.8316        92
# 2       0.8316        92
# 3       0.1280        95
# 4       0.8316        92
# 5       0.0000       122
# 6       0.0000       100
# 7       0.0000        95
# 8       0.8316        92
# 9       0.8316        92
# 10      0.8316        92
# 11      0.8316        92
# 12      0.8316        92
# 13      0.8316        92
# 14      0.8316        92
# 15      0.8316        92
# 16      0.0000       122
# 17      0.8316        92
# 18      0.8316        92
# 19      0.0000        97
# 20      0.8316        92
# 21      0.8316        92
# 22      0.8316        92
# 23      0.8316        92
# 24      0.8316        92
# 25      0.8316        92
# 26      0.8316        92
# 27      0.8316        92
# 28      0.8316        92
# 29      0.3182        71
# ...        ...       ...
# 1328    0.1406        81
# 1329    0.0000       100
# 1330    0.0000        83
# 1331    0.0000        99
# 1332    0.0000       105
# 1333    0.0000        98
# 1334   -0.2263       111
# 1335    0.0000        77
# 1336    0.0000        97
# 1337    0.0000        85
# 1338    0.9031        99
# 1339    0.0000        97
# 1340    0.0000        91
# 1341    0.0000        91
# 1342    0.0000       111
# 1343    0.0000       100
# 1344    0.0000       100
# 1345    0.0000        91
# 1346    0.0000        95
# 1347   -0.2960        93
# 1348    0.0000        38
# 1349    0.0000        91
# 1350    0.0000       100
# 1351    0.0000        97
# 1352    0.0000        86
# 1353    0.0000       105
# 1354    0.0000       105
# 1355    0.7003        83
# 1356    0.0000       104
# 1357    0.0000        97
#
# [1358 rows x 2 columns]

# %%
x2
# Out:
#       compound  text_len
# 0      -0.4939        89
# 1       0.0000        98
# 2       0.0000        98
# 3       0.0000       100
# 4       0.0000       100
# 5       0.0000       102
# 6       0.0000        97
# 7      -0.2263       111
# 8       0.0000        77
# 9       0.0000        82
# 10      0.0000        91
# 11      0.0000        74
# 12      0.0000        78
# 13      0.0000        77
# 14      0.3400        83
# 15      0.0000       102
# 16      0.0000       100
# 17      0.0000        85
# 18      0.0000        82
# 19     -0.2732        85
# 20      0.0000        78
# 21      0.0000        53
# 22      0.0000        96
# 23      0.0000        99
# 24      0.0000        96
# 25      0.0000       102
# 26      0.0000       100
# 27      0.0000        82
# 28      0.0000        78
# 29      0.4215       115
# ...        ...       ...
# 2250    0.0000        93
# 2251    0.0000        82
# 2252    0.0000        96
# 2253    0.0000        97
# 2254   -0.6705        98
# 2255    0.0000       102
# 2256    0.0000        99
# 2257   -0.6705        96
# 2258    0.8316        92
# 2259    0.8316        92
# 2260    0.0000       100
# 2261   -0.2500       112
# 2262   -0.2500       123
# 2263    0.8316        92
# 2264    0.0000        97
# 2265    0.0000       102
# 2266    0.0000        52
# 2267    0.0000        97
# 2268    0.8316        92
# 2269    0.0000        98
# 2270    0.8316        92
# 2271    0.8316        92
# 2272    0.8316        92
# 2273    0.3612       113
# 2274    0.8316        92
# 2275    0.0000        96
# 2276    0.0000        95
# 2277    0.0000        52
# 2278    0.0000        85
# 2279    0.0000       100
#
# [2280 rows x 2 columns]

# %% [markdown]
# ### 5. Statistical Analysis

# %%
comp_mean1 = np.mean(clean_tweets1['compound'])
comp_mean1
#slightly positive sentiment on average

# %%
comp_mean2 = np.mean(clean_tweets2['compound'])
comp_mean2

# %%
sd1 = np.std(clean_tweets1['compound'])
sd1

# %%
sd2 = np.std(clean_tweets2['compound'])
sd2

# %% [markdown]
# ### Since R studio has better packages for statistical analysis, I will perform the second part of my analysis in R and please refer to the R file.
